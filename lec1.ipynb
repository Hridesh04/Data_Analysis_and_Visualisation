# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HRSHUKL\Downloads\archive\Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['Gender'] == 'Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
df[(df['Gender']=='Male') & (df['Geography']=='France')]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531   Bartlett          822    France   Male   50
# 8             9    15792365         He          501    France   Male   44
# 9            10    15592389         H?          684    France   Male   27
# 10           11    15767821     Bearce          528    France   Male   31
# 20           21    15577657   McDonald          732    France   Male   41
# ...         ...         ...        ...          ...       ...    ...  ...
# 9985       9986    15586914     Nepean          659    France   Male   36
# 9988       9989    15589329    Pirozzi          775    France   Male   30
# 9993       9994    15569266     Rahman          644    France   Male   28
# 9995       9996    15606229   Obijiaku          771    France   Male   39
# 9996       9997    15569892  Johnstone          516    France   Male   35
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
## How many Disctinct values are present in a specific Columns

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.shape[0]
# Out:
# 10000

# %%
100 * df['Geography'].value_counts()/df.shape[0]
# Out:
# Geography
# France     50.14
# Germany    25.09
# Spain      24.77
# Name: count, dtype: float64

# %%
# if we don't want to calculate like this the we have a simpler way to solve this
100*df['Geography'].value_counts(normalize=True)
# Out:
# Geography
# France     50.14
# Germany    25.09
# Spain      24.77
# Name: proportion, dtype: float64

# %% [markdown]
# ## How to Group the Data

# %%
df.groupby('Gender').agg({'Tenure': 'mean'})
# Out:
#           Tenure
# Gender
# Female  4.966102
# Male    5.051677
