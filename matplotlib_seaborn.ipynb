# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HRSHUKL\Downloads\archive\WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(df['tenure'])
# Out:
# C:\Users\HRSHUKL\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# now convert histogram as density courve

# %%
sns.displot(df['tenure'], kind = 'kde') # type: ignore
# this desity graph helps us to get the knowledge of peaks of customer
# Out:
# C:\Users\HRSHUKL\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['tenure'], kind = 'kde',height=2,aspect=2)
# Out:
# C:\Users\HRSHUKL\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['tenure'], kind = 'kde',height=3,aspect=3)
# Out:
# C:\Users\HRSHUKL\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x = df['tenure'])
# Out:
# <Axes: xlabel='tenure'>

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x = df['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x = df[df['Churn']=='Yes']['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x = df[df['Churn']=='No']['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
# now we can put them side by side to understand more easlyi

# %%
plt.figure(figsize=(10,2))

plt.subplot(1,2,1)
plt.title("Churn montlhy charges")
sns.boxplot(x = df[df['Churn']=='Yes']['MonthlyCharges'])
plt.subplot(1,2,2)
plt.title("Non-Churn montlhy charges")
sns.boxplot(x = df[df['Churn']=='No']['MonthlyCharges'])
# Out:
# <Axes: title={'center': 'Non-Churn montlhy charges'}, xlabel='MonthlyCharges'>

# %%
sns.boxplot(x = df['Churn'], y = df['MonthlyCharges'])
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
sns.boxplot(y = df['Churn'], x = df['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Churn'>

# %% [markdown]
# ### How to plot Categorical Data

# %%
x = ['A','B','C']
y = [98,56,78]

# %%
sns.barplot(x=x,y=y)
# Out:
# <Axes: >

# %%
a=df['gender'].value_counts().reset_index()
a
# Out:
#    gender  count
# 0    Male   3555
# 1  Female   3488

# %%
# a has columns 'gender' and 'count'
sns.barplot(x='gender', y='count', data=a)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender distribution')
# Out:
# Text(0.5, 1.0, 'Gender distribution')
